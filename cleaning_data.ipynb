# %%
import pandas as pd 
#files being loaded
missing_data_to_find= "Resources/missing_grades.csv"
missing_data_df= pd.read_csv(missing_data_to_find)
missing_data_df
# Out:
#    Student ID       student_name gender grade  reading_score  math_score
# 0           0       Paul Bradley      M   9th           66.0        79.0
# 1           1       Victor Smith      M  12th           94.0        61.0
# 2           2    Kevin Rodriguez      M  12th            NaN        60.0
# 3           3  Dr. Richard Scott      M  12th           67.0        58.0
# 4           4         Bonnie Ray      F   9th           97.0        84.0
# 5           5      Bryan Miranda      M   9th           94.0         NaN
# 6           6      Sheena Carter      F  11th           82.0        80.0
# 7           7       Nicole Baker      F  12th           96.0        69.0

# %%
missing_data_df.count()
#missing data from reading score and math- those values arent in line
# Out:
# Student ID       8
# student_name     8
# gender           8
# grade            8
# reading_score    7
# math_score       7
# dtype: int64

# %%
missing_data_df.isnull().sum()
#shows the missing values are in reading and math
# Out:
# Student ID       0
# student_name     0
# gender           0
# grade            0
# reading_score    1
# math_score       1
# dtype: int64

# %%
#missing_data_df.dropna()
#.dropna() literally drops the NA values- probs not the best 
#youre essentially removing a person from the data set which could 
#be important
# Out:
#    Student ID       student_name gender grade  reading_score  math_score
# 0           0       Paul Bradley      M   9th           66.0        79.0
# 1           1       Victor Smith      M  12th           94.0        61.0
# 3           3  Dr. Richard Scott      M  12th           67.0        58.0
# 4           4         Bonnie Ray      F   9th           97.0        84.0
# 6           6      Sheena Carter      F  11th           82.0        80.0
# 7           7       Nicole Baker      F  12th           96.0        69.0

# %%
missing_data_df.fillna(85)
#.fillna() fills the na value- usually 0- since thats its true value
# Out:
#    Student ID       student_name gender grade  reading_score  math_score
# 0           0       Paul Bradley      M   9th           66.0        79.0
# 1           1       Victor Smith      M  12th           94.0        61.0
# 2           2    Kevin Rodriguez      M  12th           85.0        60.0
# 3           3  Dr. Richard Scott      M  12th           67.0        58.0
# 4           4         Bonnie Ray      F   9th           97.0        84.0
# 5           5      Bryan Miranda      M   9th           94.0        85.0
# 6           6      Sheena Carter      F  11th           82.0        80.0
# 7           7       Nicole Baker      F  12th           96.0        69.0

# %%
prefixes_suffixes = ["Dr. ", "Mr. ","Ms. ", "Mrs. ", "Miss ", " MD", " DDS", " DVM", " PhD"]
for word in prefixes_suffixes:
    student_data_df["student_name"] = student_data_df["student_name"].str.replace(word,"")
print(student_data_df["student_name"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/0_/xtx966m51wjcwqh0286ltxfc0000gn/T/ipykernel_73610/2262979370.py in <module>
#       1 prefixes_suffixes = ["Dr. ", "Mr. ","Ms. ", "Mrs. ", "Miss ", " MD", " DDS", " DVM", " PhD"]
#       2 for word in prefixes_suffixes:
# ----> 3     student_data_df["student_name"] = student_data_df["student_name"].str.replace(word,"")
#       4 print(student_data_df["student_name"])
#
# NameError: name 'student_data_df' is not defined
